# %%
import construction_helpers as ch # Needed for @ auto-alignment
import data_structure.Category as cat
import data_structure.Numeric as nm
import data_structure.Operators as ops
import data_structure.Term as fd
import display as dpl

# %%
''' Attention '''

qk_matmul = ops.Einops.template('q d, x d -> q x')
softmax = ops.SoftMax.template()
sv_matmul = ops.Einops.template('q x, x d -> q d')
attention = qk_matmul @ softmax @ sv_matmul

dpl.print_category(attention)

# %%
''' Labeled Attention '''

lilac = '#C5BEDF'
light_green = '#CCE7CF'
qk_matmul = cat.Block.template(qk_matmul, title='QK MatMul', fill_color=lilac)
softmax = cat.Block.template(softmax, title='SoftMax', fill_color=light_green)
sv_matmul = cat.Block.template(sv_matmul, title='SV MatMul', fill_color=lilac)
attention = qk_matmul @ softmax @ sv_matmul
dpl.print_category(attention)

# %%
import asyncio
import websocket_transfer.websockets_transfer as wst

await wst.send_term(attention)
